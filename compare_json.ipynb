# %%
import json

# JSON 데이터 불러오기
with open('augmented_m_w_balanced_train_baseline+BM25_roberta_large_b16.json', 'r', encoding='utf-8') as f:
    data1 = json.load(f)
    
with open('baseline+BM25_roberta_large_b16.json', 'r', encoding='utf-8') as f:
    data2 = json.load(f)

# 공통 키 찾기
common_keys = set(data1.keys()) & set(data2.keys())

# 값이 다른 공통 키 찾기
different_values = {key: (data1[key], data2[key]) for key in common_keys if data1[key] != data2[key]}

# 값이 다르지만 서로 포함하는 공통 키 찾기
different_but_contain_values = {key: (data1[key], data2[key]) for key in common_keys if (data1[key] != data2[key]) & ((data1[key] in data2[key]) | (data2[key] in data1[key]))}

# 첫 번째 데이터에만 있는 값 찾기
unique_to_data1 = set(data1.values()) - set(data2.values())

# 두 번째 데이터에만 있는 값 찾기
unique_to_data2 = set(data2.values()) - set(data1.values())

# 결과 출력
print(f"공통 키 중에서 값이 다른 키와 해당 값들: {different_values}")
print(f"일치율: {(len(data1)-len(different_values))/len(data1)*100}")
print(f"공통 키 중에서 값이 다르지만 서로 포함하는 키와 해당 값들: {different_but_contain_values}")
print(f"포함율: {(len(data1)-len(different_values)+len(different_but_contain_values))/len(data1)*100}")
print(f"첫 번째 데이터에만 있는 값: {unique_to_data1}")
print(f"두 번째 데이터에만 있는 값: {unique_to_data2}")
# Out:
# 공통 키 중에서 값이 다른 키와 해당 값들: {'mrc-1-000536': ('양극화', '장래의 시장 상황이 불투명하다면'), 'mrc-0-003385': ('1584년', '18세기 중반'), 'mrc-0-003755': ('귀족회의', '권문세족'), 'mrc-1-000580': ('미카사', '히스토리아가'), 'mrc-1-001517': ('강원도관찰사', '강원도 관찰사'), 'mrc-0-003331': ('1억원', '역 라돈변환'), 'mrc-1-001545': ('점액', '날개'), 'mrc-0-002414': ('왼발', '기계적인 외관'), 'mrc-0-001757': ('나 이대로 괜찮을까', '《私このままでいいのかな》(나 이대로 괜찮을까)'), 'mrc-0-003763': ('『조상경', '광배(光背)의 뒷면'), 'mrc-0-005108': ('아프로디테의 사랑을 받았던 소년 아도니스', 'Baptiste André Guillot)'), 'mrc-0-003870': ('도시구', '1,013개'), 'mrc-0-004531': ('거북선', '판옥선'), 'mrc-0-003639': ("'온' (ón)", '탑'), 'mrc-1-000094': ('구와바라', '구와바라 다케오(桑原武夫, 교토대 명예교수)'), 'mrc-0-001445': ('1915년', '1774년'), 'mrc-0-000576': ('스탈린', '아돌프 히틀러의 나치 정당'), 'mrc-0-001699': ('SI', 'SI 단위계'), 'mrc-0-001931': ('제4기갑군 등으로 구성되어 있었다. 그 부대들 중에서는 제6군', 'B집단군'), 'mrc-0-000944': ('수직하중과 회전력', '물'), 'mrc-1-000227': ('웅게른슈테른베르크', '유표군'), 'mrc-0-001379': ('CA 오사수', 'FC 로리앙'), 'mrc-0-003821': ('영국', '잉글랜드'), 'mrc-0-002848': ('루디 라모스', '케빈 베이컨'), 'mrc-0-004880': ('남미 자브', '남미 자브로'), 'mrc-1-001523': ('기욤', '니 기븐'), 'mrc-1-000627': ('1967년 11월 15일', '1967년 8월 16일'), 'mrc-1-001394': ('바라아', '"바라아"'), 'mrc-0-004345': ('1991년', '2014년'), 'mrc-0-004460': ('러블리 안대', '경영난'), 'mrc-1-000769': ('당군', '이세적의 당군'), 'mrc-1-000651': ('대', '서울시 종로구 종로4가 동원예식장 뒤뜰'), 'mrc-0-003236': ('베를린', '프로이센'), 'mrc-1-001269': ('를르네 지카르트', '패닌'), 'mrc-1-001229': ('"그림 그리기"', 'OekakiBBS'), 'mrc-0-000439': ('점쟁이', '리처드 말킨'), 'mrc-0-002170': ('소우기', '《소우기》'), 'mrc-0-004085': ('맥헨리', '로버트 맥컨'), 'mrc-0-004862': ('정통 칼리파', '정통 칼리파(Al-Khalifah Ar-Rashid)'), 'mrc-0-000304': ('1919년 10월 1일자', '1919년 10월 1일'), 'mrc-0-004855': ('1919년', '1961년'), 'mrc-1-001543': ('선셋 대로', '《선셋 대로》'), 'mrc-0-001415': ('SNS미디어본부장', '국민편익위원회 SNS미디어본부장'), 'mrc-1-000870': ('≪바람 속에서 벌거벗고', '"지(智)"'), 'mrc-1-000573': ('큰곰자리 이동성군', '제타 계'), 'mrc-0-001272': ('고현', '고현(苦縣)'), 'mrc-0-002618': ('이항직', '기호흥학회'), 'mrc-0-005387': ('자동차 폐기장', '전당포'), 'mrc-0-005215': ('입석대', '입석대(立石臺)'), 'mrc-1-001624': ('가즈사 부수의 난', '가즈사 국'), 'mrc-0-001034': ('수성 구조는 활동적인가?', '검찰은 역할 축소'), 'mrc-1-000653': ('베텔게우스(Betelgeuse) 근처', '베텔게우스(Betelgeuse) 근처의 작은 행성'), 'mrc-0-003085': ('80~90%', '80~90% 확률'), 'mrc-1-001619': ('시게노부 후사코', '사이고 다카모리(西鄕隆盛)'), 'mrc-0-004594': ('중장기적 인구감소', '교육 및 문화 교류를 통해 미국 사람들과 다른 국가 사람들 간의 상호 이해를 높이는 것'), 'mrc-0-003454': ('샤를마뉴 황제', '1986년'), 'mrc-1-000256': ('이인', '사만다'), 'mrc-1-000993': ('유두', '며느리발톱'), 'mrc-1-001554': ('크라쿠프 대학', '야기옐론 대학'), 'mrc-0-000288': ('아리스타르코스', '파울루 프레이리의 ‘페다고지’'), 'mrc-0-001682': ('석방', '종신형'), 'mrc-0-001206': ('2018년', '2013년'), 'mrc-0-003628': ('판권관리', '공유 필명'), 'mrc-1-000218': ('≪나체즈 족≫', '보러블 3부작'), 'mrc-0-004579': ('루이지애나주 센터빌', '도쿄'), 'mrc-0-001346': ('호해', '대왕 유항'), 'mrc-0-001326': ('‘자유’', '‘자유’지에'), 'mrc-0-004755': ('소련 굴라그 강제 수용소', '습지대'), 'mrc-0-005411': ('켈리 오브라이언', '사비나'), 'mrc-0-001026': ('170여 편', '86 편의'), 'mrc-0-003670': ('자한기르', '덩치 큰 어른'), 'mrc-1-001721': ('아버지', '조카 윤보선'), 'mrc-0-002074': ('북한군의 진격을 지연', '라운드 기반으로 진행되며, 시간'), 'mrc-0-000760': ('공개 프록시', '공개 프록시를 사용하면 해당 프록시 서버의 IP 주소'), 'mrc-0-003105': ('‘4·19 폭동설’', '폭동'), 'mrc-0-001961': ('무역풍', '남서풍'), 'mrc-0-003043': ('경시청 수사1과', '유니버설 뮤직'), 'mrc-0-002518': ('IMF 외환위기', '1990년대 후반'), 'mrc-0-003365': ('비공식 굿즈', "'비공식 굿즈'"), 'mrc-0-003170': ('1994년', '1994'), 'mrc-0-001659': ('원', '유리노모스'), 'mrc-0-002188': ('104번 위치의 글루탐산', '글루탐산'), 'mrc-0-003031': ('수 양제', '수 양제(煬帝)'), 'mrc-0-004159': ('해 (지지)단계', '스토리 보드'), 'mrc-0-001847': ('2세', '호해'), 'mrc-0-004392': ('뇌 일부', '뇌'), 'mrc-0-002651': ('스뮈츠는', '팔레스타인'), 'mrc-0-002191': ('대통령인 빌헬름 미클라스', '빌헬름 미클라스'), 'mrc-0-002130': ('러시아', '러시아 제국'), 'mrc-0-002947': ('평산', '신고전주의'), 'mrc-0-000527': ('《곤충기(昆蟲記)》', '과학'), 'mrc-0-000028': ('모하메드 파라 아이디드를 암살', '모하메드 파라 아이디드'), 'mrc-0-000668': ('시캉브르(Sicambres)', '북부 아크로폴리스 33번 신전 아래'), 'mrc-0-000734': ('외국인', '언더우드 박사'), 'mrc-0-002265': ('1935년', '1932년'), 'mrc-0-000500': ('2008년', '2009년'), 'mrc-0-004510': ('인체의 치수(인체측정학의 측정 기준)', '인체의 치수'), 'mrc-1-001727': ('수영공원', '부산 ...
# 일치율: 61.0
# 공통 키 중에서 값이 다르지만 서로 포함하는 키와 해당 값들: {'mrc-0-001757': ('나 이대로 괜찮을까', '《私このままでいいのかな》(나 이대로 괜찮을까)'), 'mrc-1-000094': ('구와바라', '구와바라 다케오(桑原武夫, 교토대 명예교수)'), 'mrc-0-001699': ('SI', 'SI 단위계'), 'mrc-0-004880': ('남미 자브', '남미 자브로'), 'mrc-1-001394': ('바라아', '"바라아"'), 'mrc-1-000769': ('당군', '이세적의 당군'), 'mrc-0-002170': ('소우기', '《소우기》'), 'mrc-0-004862': ('정통 칼리파', '정통 칼리파(Al-Khalifah Ar-Rashid)'), 'mrc-0-000304': ('1919년 10월 1일자', '1919년 10월 1일'), 'mrc-1-001543': ('선셋 대로', '《선셋 대로》'), 'mrc-0-001415': ('SNS미디어본부장', '국민편익위원회 SNS미디어본부장'), 'mrc-0-001272': ('고현', '고현(苦縣)'), 'mrc-0-005215': ('입석대', '입석대(立石臺)'), 'mrc-1-000653': ('베텔게우스(Betelgeuse) 근처', '베텔게우스(Betelgeuse) 근처의 작은 행성'), 'mrc-0-003085': ('80~90%', '80~90% 확률'), 'mrc-0-001326': ('‘자유’', '‘자유’지에'), 'mrc-0-000760': ('공개 프록시', '공개 프록시를 사용하면 해당 프록시 서버의 IP 주소'), 'mrc-0-003105': ('‘4·19 폭동설’', '폭동'), 'mrc-0-003365': ('비공식 굿즈', "'비공식 굿즈'"), 'mrc-0-003170': ('1994년', '1994'), 'mrc-0-002188': ('104번 위치의 글루탐산', '글루탐산'), 'mrc-0-003031': ('수 양제', '수 양제(煬帝)'), 'mrc-0-004392': ('뇌 일부', '뇌'), 'mrc-0-002191': ('대통령인 빌헬름 미클라스', '빌헬름 미클라스'), 'mrc-0-002130': ('러시아', '러시아 제국'), 'mrc-0-000028': ('모하메드 파라 아이디드를 암살', '모하메드 파라 아이디드'), 'mrc-0-004510': ('인체의 치수(인체측정학의 측정 기준)', '인체의 치수'), 'mrc-1-000008': ('외투', '히틀러의 외투'), 'mrc-0-003441': ('라트비아', '라트비아와 리투아니아 인민전선'), 'mrc-0-003356': ('언더우드', '언더우드(Underwood)박사'), 'mrc-0-002525': ('<<종횡무진 한국경제>', '<<종횡무진 한국경제>>'), 'mrc-1-000086': ('이승만, 김구', '이승만'), 'mrc-0-001574': ('피오렐로 라과디아와 좌익의 비토 마캔토니오', '피오렐로 라과디아'), 'mrc-1-001592': ('저녁', '매일 저녁'), 'mrc-1-000650': ('불투명하고 착색된 광물', '광물'), 'mrc-1-001829': ('진경동', '진경동(秦慶童)'), 'mrc-0-000434': ('인질이 된 다케치요(이에야스)의 양육을 위해', '다케치요(이에야스)의 양육을 위해'), 'mrc-0-005422': ('옥시전 디스트로이어', '옥시전 디스트로이어의 비밀'), 'mrc-1-001025': ('티탄즈', '특수부대「티탄즈」'), 'mrc-0-000395': ('후쿠도메 시게루 중장', '제2항공함대 사령관 후쿠도메 시게루 중장'), 'mrc-0-003970': ('교토 본선과 센리 선', '센리 선'), 'mrc-1-000524': ('밀로셰비치', '슬로보단 밀로셰비치'), 'mrc-0-004484': ('전라남도', '전라남도 지역'), 'mrc-1-000621': ('간석기', '간석기(마제석기)'), 'mrc-0-000607': ('큰 송곳니', '비정상적으로 큰 송곳니'), 'mrc-0-000032': ('2004년의 국방부 보고서', '국방부 보고서'), 'mrc-0-001940': ('경문왕', '신라 경문왕'), 'mrc-0-000499': ('자전축 경사', '극단적인 자전축 경사'), 'mrc-1-000841': ('한진창', '사돈인 한진창'), 'mrc-0-003596': ('일요등교 지시', '부당한 일요등교 지시'), 'mrc-1-001239': ('쉴드 빔 2개', '쉴드 빔'), 'mrc-1-001370': ('국제법', '전시국제법'), 'mrc-0-001105': ('실존주의 사상', '실존주의'), 'mrc-0-000206': ('1848년 2월 24일 2월 혁명', '2월 혁명'), 'mrc-0-002676': ('아루', '아루에'), 'mrc-0-000328': ('사실주의적인', '사실주의'), 'mrc-0-002092': ('소방공무원법', '「소방공무원법」'), 'mrc-0-002289': ('남해안 연안일대', '남해안 연안일대의 요충지'), 'mrc-1-001113': ('냉전 종식', '냉전'), 'mrc-0-003038': ('에우리아의 요한', '에피루스의 주교 에우리아의 요한'), 'mrc-1-000235': ('농지', "'농지'(農地)"), 'mrc-0-002654': ('사운드클라우드', '본인 사운드클라우드 계정'), 'mrc-0-002895': ('칼라치 전방 약250km 지점', '칼라치'), 'mrc-0-000150': ('3-3', '3-3 무승부'), 'mrc-0-004335': ('일간 뉴욕타임스', '뉴욕타임스'), 'mrc-1-001071': ('남자아이 빈을 데려다 양자로 삼는다.', '남자아이 빈'), 'mrc-0-001241': ('상업', '상업 분야')}
# 포함율: 72.16666666666667
# 첫 번째 데이터에만 있는 값: {'켈리 오브라이언', "'나는 참된 보통 선거를 원한다'", '북한군의 진격을 지연', '에우메네스', '원', '강원도관찰사', '진무양', '자한기르', '벤자민 바커', '카네츠 신베에', '고현', '1991년', '레긴', '해련스님', '1915년', '판권관리', '초음파식 가습기', '이항직', '아루', '1억원', '외투', '귀족회의', '모하메드 파라 아이디드를 암살', '가압 카트리지', '밀로셰비치', '나 이대로 괜찮을까', '<<종횡무진 한국경제>', '베텔게우스(Betelgeuse) 근처', '가즈사 부수의 난', '베를린', '종 맨 위', '안시성 전투', '교육 평론가', "'법봉'", '전라남도', '서독', '대통령인 빌헬름 미클라스', '대', '진경동', '인질이 된 다케치요(이에야스)의 양육을 위해', '후세인 이븐 무함마드 차으르 테긴', '고대 로마 역사가 리비우스', '이승만, 김구', '과학자', '옥시전 디스트로이어', '노포탑(露砲塔)', '저녁', '해 (지지)단계', '수영공원', '수 양제', '남미 자브', '디에프 항', '신춘문예공모전', '피오렐로 라과디아와 좌익의 비토 마캔토니오', '수성 구조는 활동적인가?', '군토구미', '뇌 일부', '점액', '백병계열군', '통인 주기', '제4기갑군 등으로 구성되어 있었다. 그 부대들 중에서는 제6군', '아델로스폰딜리목', '도시구', '건강증서', '경시청 수사1과', '입석대', '칼라치 전방 약250km 지점', '곳샬크', '미카사', '1811년', '간석기', '시캉브르(Sicambres)', '아유미', '독일', '게임플레이', '시게노부 후사코', '사실주의적인', '1848년 2월 24일 2월 혁명', '소방공무원법', '백제금동대향로', '1309년', '보신 전쟁', '수직하중과 회전력', '상어 공격 전문가', '양극화', '스탈린', '아라라기 코요미', '미술과', '17세기대로 넘어오면 지장보살상에서 두건을 확인하기 쉽지 않으며, 일반적으로 조선후기', "'청구의 원인' 기재에서 적절한 이유를 골라서 특정하면 된다", '불투명하고 착색된 광물', '앙굴리말라', '함정과 인력의 부족', '윌러드 밴 오먼 콰인', '개성', '기욤', '2018년', '큰 송곳니', '104번 위치의 글루탐산', '경문왕', '상업', '2세', '일요등교 지시', '남자아이 빈을 데려다 양자로 삼는다.', '윤두현 청와대 홍보수석', '115미터', '카필라 성', '한진창', '일간 뉴욕타임스', '1806년', '80~90%', '"그림 그리기"', '카시니', '중장기적 인구감소', '당군', '목재와 장작을 실어나르고자', '에우리아의 요한', '1919년', '‘자유’', '170여 편', '를르네 지카르트', '이태웅', '1935년', '1584년', '언더우드', '루벤 리마르도', '석방', '쉴드 빔 2개', '아버지', '아프로디테의 사랑을 받았던 소년 아도니스', '『조상경', '레옹 오귀스트 테오필 롬', '웅게른슈테른베르크', '인격성', '파비아', '소련 굴라그 강제 수용소', '충청북도 증평군', '왼발', '《곤충기(昆蟲記)》', '외국인', '피자헛', '루이지애나주 센터빌', '인체의 치수(인체측정학의 측정 기준)', '태풍 초이완이 마리아나 제도', '교토 본선과 센리 선', '스뮈츠는', '2차 저작물의 저자', '점쟁이', "'온' (ón)", '조선건국동맹', '러블리 안대', '≪나체즈 족≫', '요코하마', '무역풍', 'SNS미디어본부장', '막딘찌', '이인', '3-3', '세 가지', '국회의장', '24일', '유카-페카 사라스테', '기원전·후 시기', '루디 라모스', '1994년', '라트비아', '5월 8일', '독일 제국해군', '‘4·19 폭동설’', '자전축 경사', '1967년 11월 15일', '거북선', '＜빗속에서＞', '크라쿠프 대학', '자동차 폐기장', '사운드클라우드', '실존주의 사상', '남해안 연안일대', '소우기', '중간역', '민주주의의 후퇴', 'CA 오사수', '라이네크', '농지', '"파이어 건담"', '바라아', '드미트리 1세', '티탄즈', '유두', '≪바람 속에서 벌거벗고', '2004년의 국방부 보고서', '구와바라', '1919년 10월 1일자', '괜찮다고', '아리스타르코스', '베드로좌', '정치평론면 편집장', '비공식 굿즈', '냉전 종식', '다니엘 슈타이벨트', '큰곰자리 이동성군', '마르크 오버르마르스', '선셋 대로', '삼국시대', '국제법', '웅기탁', '서구 감천동 뒷산', '"한국이 강제 징용 합의에 대한 기존의 약속을 어겼다"', 'IMF 외환위기', '천공', '《나무 그림》', '대막리지 연개소문', '러시아', '마라의 박해와 암살', '맥헨리', '샤를마뉴 황제', '투지와 결정력', '공개 프록시', '정통 칼리파', '한국노총', '평산', '안양면사무소', '길앞잡이', '마라도나', 'SI', '후쿠도메 시게루 중장'}
# 두 번째 데이터에만 있는 값: {'제우스', '초음파 가습기', 'Baptiste André Guillot)', '유표군', '더블린', '자인단오-한장군 놀이', '프리큐어들', "'Beetles(딱정벌레)'", '케빈 베이컨', '제2항공함대 사령관 후쿠도메 시게루 중장', '옥시전 디스트로이어의 비밀', '암수딴그루', '트렌토', '2013년', '판옥선', '라운드 기반으로 진행되며, 시간', '센리 선', '러시아 제국', '조선시대', '부잣집', "'구슬이'", '다이요', '대왕 유항', '다케치요(이에야스)의 양육을 위해', '오코 카무', '한국인터넷자율정책기구(KISO)', '야기옐론 대학', '영선국민학교', '사이고 다카모리(西鄕隆盛)', 'FC 로리앙', '문장대', '아시카가 쇼군가와', '1986년', '국방부 보고서', '조토 디 본도네', '기계적인 외관', '요세푸스', '패닌', '피오렐로 라과디아', '스트레리치아 여학원', '시릴 라마포사 대통령', '구와바라 다케오(桑原武夫, 교토대 명예교수)', '간석기(마제석기)', '북부 아크로폴리스 33번 신전 아래', '루돌프 대공', '2009년', '2월 혁명', '"지(智)"', '《소우기》', '아사히 신문', '스토리 보드', '1795년', '성경의 요한 계시록', '시디어스', '"건강 증서"', '쿠페', '1932년', '본인 사운드클라우드 계정', '슬로보단 밀로셰비치', '사만다', '1994', '3-3 무승부', '베텔게우스(Betelgeuse) 근처의 작은 행성', '손가락', '2013년 7월', '전시국제법', '며느리발톱', '급진파', '≪악령≫', '비정상적으로 큰 송곳니', '빌헬름 미클라스', '폴 베나세라프', '국민편익위원회 SNS미디어본부장', '실존주의', '과학', '1990년대 후반', '3미터', '남서풍', '주정부', '도쿄', '1,013개', '츠와몬', '5월 7일', '사실주의', 'STS-34', '1774년', '날개', '역 라돈변환', '입석대(立石臺)', '이승만', '경영난', '사비나', '광배(光背)의 뒷면', '"수출 규제 해제 요청"', '에피루스의 주교 에우리아의 요한', '서면 또는 구술', '기호흥학회', '공개 프록시를 사용하면 해당 프록시 서버의 IP 주소', '뉴욕타임스', '한국노병회(韓國勞兵會)', '이세적의 당군', '"바라아"', '1919년 10월 1일', '디에프 해변', '칼라치', '《선셋 대로》', '당대표', '‘자유’지에', '새정치연합 우윤근 원내대표', '리처드 말킨', '「소방공무원법」', '86 편의', '탑', '흑진주의', '유리노모스', '조선인민군', '신고전주의', '교황', '인간', '특수목적회사 M2G', '물', '시구르드', '검찰은 역할 축소', '볼가 지방', "'비공식 굿즈'", '로버트 맥컨', '남해안 연안일대의 요충지', '≪낮은 밤 외에 비길 만한 것이 없다≫', '유니버설 뮤직', '늦은 9월 14일', '교육 및 문화 교류를 통해 미국 사람들과 다른 국가 사람들 간의 상호 이해를 높이는 것', '1530년', '진경동(秦慶童)', '조카 윤보선', '말', '1967년 8월 16일', '고려 초경', '전통적인 서사', '전당포', '안드레아스', '파울루 프레이리의 ‘페다고지’', '1971년', '아루에', '히스토리아가', '신라 경문왕', '우크라이나', '80~90% 확률', 'SI 단위계', '폭동', '티아라의 보람', '고현(苦縣)', '특수부대「티탄즈」', '하이브리드 잉크 배합물', '보러블 3부작', '아돌프 히틀러의 나치 정당', '오스마르', '프로이센 왕국군', '1802년', '16', '달걀', "'농지'(農地)", '언더우드(Underwood)박사', '라트비아와 리투아니아 인민전선', '남자아이 빈', '인체의 치수', '코드', '벤저민 바커', '강원도 관찰사', '상업 분야', '《私このままでいいのかな》(나 이대로 괜찮을까)', '서울시 종로구 종로4가 동원예식장 뒤뜰', 'OekakiBBS', '언더우드 박사', '승려', '글루탐산', '안양읍사무소', '신사용 양품 가게', '18세기 중반', '피터 발스 박사', '세르비아 왕국', '극단적인 자전축 경사', '장래의 시장 상황이 불투명하다면', '1961년', '이란', '잉글랜드', '매일 저녁', 'B집단군', '니 기븐', '레이테만 전투', '미치류', '습지대', '수 양제(煬帝)', '함포', '오미이마즈 역에서 병결 및 분리를 하는 동안', "'나는 참된 보통 선거를 원한다 (我要真普選)'", '플로이드가 말을 하고 있으니 괜찮', '잡곡 보리밥', '부당한 일요등교 지시', '덩치 큰 어른', '고려초기', '응봉산 중턱', '제타 계', '미하일린', '권문세족', '냉전', '공유 필명', '남미 자브로', '광물', '금산전투', '타카마츠 히데오', '맹세', '부산 해안 방어', '백병전', '프로이센', '도바 후시미 전투', '선수들의 이름값', '쉴드 빔', '뇌', '2014년', '대의제도', '가즈사 국', '모하메드 파라 아이디드', '전라남도 지역', '정통 칼리파(Al-Khalifah Ar-Rashid)', '아비도스', '히틀러의 외투', '티에리 앙리', '동탁은잔(銅托銀盞)', '<<종횡무진 한국경제>>', '사돈인 한진창'}
